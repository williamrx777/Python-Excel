# %%
import pandas as pd

# %%
email = pd.read_excel('CHECK LIST.xlsm', sheet_name='E-MAILS')

# %%
display(email)
# Out:
#                              E-MAILS                      Unnamed: 1  \
# 0                            USUÁRIO                         Coluna1
# 1                     Alvaro Andrier               alvaro@gmr.com.br
# 2                  Andrezza da Silva       andrezza.silva@gmr.com.br
# 3    Antonio Rogério Sobral de Souza  representante.macae@gmr.com.br
# 4                   Andressa Martins     andressa.martins@gmr.com.br
# ..                               ...                             ...
# 106                       Magno Reis             magno.es@gmr.com.br
# 107                     Luana Santos             luana.es@gmr.com.br
# 108                Isabela Resezende      isabela.resende@gmr.com.br
# 109              Matheus Vasconcelos  matheus.vasconcelos@gmr.com.br
# 110                    Wendel Bastos        wendel.bastos@gmr.com.br
#
#     Unnamed: 2    Unnamed: 3      Unnamed: 4  \
# 0       Status         SENHA     NOVA SENHA2
# ...

# %%
inventario = pd.read_excel('CHECK LIST.xlsm', usecols="W:X" )

# %%
head_inventario = inventario.head(91)

# %%
display(head_inventario)
# Out:
#       Unnamed: 22    Unnamed: 23
# 0     FUNCIONÁRIO          SETOR
# 1      EQUINOVIDA     EQUINOVIDA
# 2      EQUINOVIDA     EQUINOVIDA
# 3   ESTOQUE/PALET  ESTOQUE/PALET
# 4   ESTOQUE/PALET  ESTOQUE/PALET
# ..            ...            ...
# 86        LACIELE     ANA DANTAS
# 87            NaN            NaN
# 88    FUNCIONÁRIO          SETOR
# 89        RODRIGO         GALPÃO
# 90        MARCELO         GALPÃO
#
# [91 rows x 2 columns]

# %%
tudo = pd.read_excel('CHECK LIST.xlsm', sheet_name=None)

# %%
display(tudo)
# Out:
# {'INVENTÁRIO PC':       VENDAS - 2º ANDAR           Unnamed: 1 Unnamed: 2      Unnamed: 3  \
#  0                COMPRA             GARANTIA      IDADE          MODELO
#  1                   NaN                  NaN        NaN         MONTADO
#  2   2008-10-10 00:00:00  2011-10-11 00:00:00         16    OPTIPLEX 330
#  3   2006-03-13 00:00:00  2009-03-13 00:00:00         18  OPTIPLEX GX620
#  4   2006-03-18 00:00:00  2009-03-18 00:00:00         18   OPTIPLEX 170L
#  ..                  ...                  ...        ...             ...
#  87   GALPÃO - ENGELUMEN                  NaN        NaN             NaN
#  88               COMPRA             GARANTIA      IDADE          MODELO
#  89  2011-07-07 00:00:00  2012-08-10 00:00:00         13   PROBOOK 4320S
#  90  2013-06-27 00:00:00  2016-06-28 00:00:00         11    OPTPLEX 3010
#  91  2010-11-25 00:00:00  2013-11-26 00:00:00         14    OPTIPLEX 780
#
#                                             Unnamed: 4   Unnamed: 5  \
# ...
